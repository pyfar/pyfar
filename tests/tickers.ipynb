# %%
"""
=============
Tick locators
=============

Show the different tick locators.
"""
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import haiopy.plot.ticker as hticker


# Setup a plot such that only the bottom spine is shown
def setup(ax):
    ax.spines['right'].set_color('none')
    ax.spines['left'].set_color('none')
    ax.yaxis.set_major_locator(ticker.NullLocator())
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.tick_params(which='major', width=1.00)
    ax.tick_params(which='major', length=5)
    ax.tick_params(which='minor', width=0.75)
    ax.tick_params(which='minor', length=2.5)
    ax.set_xlim(0, 5)
    ax.set_ylim(0, 1)
    ax.patch.set_alpha(0.0)


plt.figure(figsize=(8, 3))
n = 5

# Null Locator
ax = plt.subplot(n, 1, 1)
setup(ax)
ax.xaxis.set_major_locator(ticker.NullLocator())
ax.xaxis.set_minor_locator(ticker.NullLocator())
ax.text(0.0, 0.1, "NullLocator()", fontsize=14, transform=ax.transAxes)

# Log Locator
ax = plt.subplot(n, 1, 2)
setup(ax)
ax.set_xlim(20, 20e3)
ax.set_xscale('log')
ax.xaxis.set_major_locator(ticker.LogLocator(base=10.0, numticks=15))
ax.text(0.0, 0.1, "LogLocator(base=10, numticks=15)",
        fontsize=15, transform=ax.transAxes)

# Log Locator ITA
ax = plt.subplot(n, 1, 3)
setup(ax)
ax.set_xlim(20, 20e3)
ax.set_xscale('log')
ax.xaxis.set_major_locator(hticker.LogLocatorITAToolbox(base=10.0, numticks=15))
ax.xaxis.set_major_formatter(hticker.LogFormatterITAToolbox(base=10.0))
ax.text(0.0, 0.1, "LogLocatorITAToolbox",
        fontsize=15, transform=ax.transAxes)

# Log Locator ITA
ax = plt.subplot(n, 1, 4)
setup(ax)
ax.set_xlim(20, 20e3)
ax.set_xscale('log')
ax.xaxis.set_major_locator(hticker.FractionalOctaveLocator())
ax.xaxis.set_minor_locator(hticker.FractionalOctaveLocator(n_fractions=3))
ax.xaxis.set_major_formatter(hticker.FractionalOctaveFormatter())
ax.xaxis.set_minor_formatter(ticker.NullFormatter())
ax.text(0.0, 0.1, "FractionalOctaveLocator",
        fontsize=15, transform=ax.transAxes)


# MultiplesFraction Locator
ax = plt.subplot(n, 1, 5)
setup(ax)
ax.set_xlim(-np.pi, np.pi)
# ax.set_xscale('log')
ax.xaxis.set_major_locator(hticker.MultipleFractionLocator(1, 4, np.pi))
ax.xaxis.set_minor_locator(hticker.MultipleFractionLocator(1, 8, np.pi))
ax.xaxis.set_major_formatter(hticker.MultipleFractionFormatter(1, 4, np.pi, r'\pi'))
ax.xaxis.set_minor_formatter(ticker.NullFormatter())
ax.text(0.0, 0.1, "MultipleFractionFormatter(1, 4, np.pi, r'\pi'))",
        fontsize=15, transform=ax.transAxes)


# Push the top of the top axes outside the figure because we only show the
# bottom spine.
plt.subplots_adjust(left=0.05, right=0.95, bottom=0.05, top=1.05)

plt.show()
# Out:
# /Users/marco/projects/python/haiopy/haiopy/fft.py:13: UserWarning: Using numpy FFT implementation.        Install pyfftw for improved performance.
#   Install pyfftw for improved performance.")
