# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import haiopy
from haiopy import Signal
from haiopy import Coordinates
from haiopy import Orientation
from haiopy import plot

import numpy as np
from scipy.io.wavfile import read
from scipy import signal as sgn


# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# %load_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-74-42adb9eb59a0> in <module>
#      11 from scipy import signal as sgn
#      12
# ---> 13 from haiopy import test_plot
#      14
#      15 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ImportError: cannot import name 'test_plot' from 'haiopy' (/Users/johannes/ITA/haiopy/haiopy/__init__.py)

# %%
test_audio_read = read('test_rir_noise.wav')
sampling_rate = test_audio_read[0]
test_audio_raw = test_audio_read[1]
test_audio_raw =test_audio_raw/ np.max(np.abs(test_audio_raw))

t = np.linspace(0, 1, 44100, endpoint=False)
squarewave = sgn.square(2 * np.pi * 440 * t)

test_signal_object = Signal(data=squarewave,
                    sampling_rate=44100,
                    domain='time',
                    signal_type='power')

# %%
ax = plot.plot_time(test_signal_object)

# %%
ax = plot.plot_time_dB(test_signal_object)

# %%
ax = plot.plot_freq(test_signal_object)

# %%
ax = plot.plot_phase(test_signal_object)

# %%
ax = plot.plot_group_delay(test_signal_object)

# %%
ax = plot.plot_spectrogram(test_signal_object, log=False)

# %%
ax = plot.plot_freq_phase(test_signal_object)

# %%
ax = plot.plot_freq_group_delay(test_signal_object)

# %%
ax = plot.plot_all(test_signal_object)
